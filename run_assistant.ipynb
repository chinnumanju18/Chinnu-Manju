# %%
import datetime
import random

def get_time():
    time = datetime.datetime.now().strftime('%I:%M %p')
    return time

def tell_joke():
    jokes = [
        "Why don't scientists trust atoms? Because they make up everything!",
        "Why did the scarecrow win an award? Because he was outstanding in his field!",
        "Why don't skeletons fight each other? They don't have the guts!"
    ]
    return random.choice(jokes)

def run_assistant():
    command = input("Enter a command: ").lower()
    if 'time' in command:
        print('The current time is ' + get_time())
    elif 'joke' in command:
        print(tell_joke())
    elif 'hello' in command:
        print('Hi!')
    elif 'how are you doing' in command:
        print('I am doing good! Thanks for asking!')
    elif 'bye' in command:
        print('Goodbye!')
        quit()
    else:
        print('Please say the command again.')

while True:
    run_assistant()
# Out:
# Enter a command: hi
# Please say the command again.
# Enter a command: time
# The current time is 03:22 PM
# Enter a command: hello
# Hi!
# Enter a command: Why don't scientists trust atoms? Because they make up everything!"
# Please say the command again.
# Enter a command: joke
# Why don't skeletons fight each other? They don't have the guts!
# Enter a command: bye
# Goodbye!
